# %% [markdown]
# <a href="https://colab.research.google.com/github/TeomanEgeSelcuk/Stock-Options/blob/main/EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Data Load

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# Load data from CSV file and parse date columns
df = pd.read_csv("drive/MyDrive/Call Options Alert System/Cleaned_data_aapl.csv", parse_dates=['QUOTE_DATE', 'EXPIRE_DATE'])

# %% [markdown]
# ## Plots

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming 'df' is your DataFrame with 'QUOTE_DATE' and 'C_LAST' columns

# # Convert 'QUOTE_DATE' to a pandas datetime object with error handling
# df['QUOTE_DATE'] = pd.to_datetime(df['QUOTE_DATE'], format='%Y-%m-%d', errors='coerce')

# # Remove rows with NaT (invalid date) values
# df = df.dropna(subset=['QUOTE_DATE'])

# # Ensure 'C_LAST' column contains numeric values (convert if needed)
# df['C_LAST'] = pd.to_numeric(df['C_LAST'], errors='coerce')

# # Remove rows with non-numeric 'C_LAST' values
# df = df.dropna(subset=['C_LAST'])

# # Sort the DataFrame by 'QUOTE_DATE'
# df.sort_values(by='QUOTE_DATE', inplace=True)

# Create the plot for call option prices
plt.figure(figsize=(12, 6))  # Set the figure size

# Plot call option prices
plt.plot(df['QUOTE_DATE'], df['C_LAST'], label='Call Option Prices', color='blue')

# Customize the plot
plt.title('Call Option Prices Over Time')
plt.xlabel('Quote Date')
plt.ylabel('Call Option Price')
plt.legend()

# Rotate x-axis labels for better readability (optional)
plt.xticks(rotation=45)

# Show the plot
plt.grid()
plt.tight_layout()
plt.show()

# %% [markdown]
# # Explore Contracts: Strike Prices and Count

# %%
# Assuming 'df' is your DataFrame

# Count the number of unique contracts based on the 'STRIKE' column
num_unique_contracts = df['STRIKE'].nunique()

print("Number of unique contracts:", num_unique_contracts)
# Out:
# Number of unique contracts: 447

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Create a histogram to show the distribution of contract counts
plt.figure(figsize=(12, 6))  # Set the figure size

# Plot a histogram of the strike prices
plt.hist(df['STRIKE'], bins=30, edgecolor='k', alpha=0.7)

# Customize the plot
plt.title('Distribution of Contract Counts by Strike Price')
plt.xlabel('Strike Price')
plt.ylabel('Count')

# Show the plot
plt.grid()
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt


# Create a bar plot to show contract counts by day
plt.figure(figsize=(12, 6))  # Set the figure size

# Group the data by 'QUOTE_DATE' and count the number of contracts for each day
contract_counts_by_day = df.groupby(df['QUOTE_DATE'].dt.date)['STRIKE'].count()

# Plot the contract counts by day
plt.hist(contract_counts_by_day.values, bins=30, edgecolor='k', alpha=0.7)

# Customize the plot
plt.title('Contract Counts by Day')
plt.xlabel('Count')
plt.ylabel('Frequency')

# Show the plot
plt.grid()
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Create a bar chart to show contract counts by month
plt.figure(figsize=(12, 6))  # Set the figure size

# Extract the month from 'QUOTE_DATE' and create a new column 'QUOTE_MONTH'
df['QUOTE_MONTH'] = df['QUOTE_DATE'].dt.month

# Group the data by 'QUOTE_MONTH' and count the number of contracts for each month
contract_counts_by_month = df.groupby('QUOTE_MONTH')['STRIKE'].count()

# Plot the contract counts by month using a bar chart
contract_counts_by_month.plot(kind='bar', edgecolor='k', alpha=0.7)

# Customize the plot
plt.title('Contract Counts by Month')
plt.xlabel('Month')
plt.ylabel('Count')

# Show the plot
plt.grid()
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Create a bar chart to show contract counts by year
plt.figure(figsize=(12, 6))  # Set the figure size

# Extract the year from 'QUOTE_DATE' and create a new column 'QUOTE_YEAR'
df['QUOTE_YEAR'] = df['QUOTE_DATE'].dt.year

# Group the data by 'QUOTE_YEAR' and count the number of contracts for each year
contract_counts_by_year = df.groupby('QUOTE_YEAR')['STRIKE'].count()

# Plot the contract counts by year using a bar chart
contract_counts_by_year.plot(kind='bar', edgecolor='k', alpha=0.7)

# Customize the plot
plt.title('Contract Counts by Year')
plt.xlabel('Year')
plt.ylabel('Count')

# Show the plot
plt.grid()
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Create a bar chart to show the count of unique strike prices for each year
plt.figure(figsize=(12, 6))  # Set the figure size

# Extract the year from 'QUOTE_DATE' and create a new column 'QUOTE_YEAR'
df['QUOTE_YEAR'] = df['QUOTE_DATE'].dt.year

# Group the data by 'QUOTE_YEAR' and count the number of unique strike prices for each year
unique_strike_counts_by_year = df.groupby('QUOTE_YEAR')['STRIKE'].nunique()

# Plot the count of unique strike prices by year using a bar chart
unique_strike_counts_by_year.plot(kind='bar', edgecolor='k', alpha=0.7)

# Customize the plot
plt.title('Count of Unique Strike Prices by Year')
plt.xlabel('Year')
plt.ylabel('Count of Unique Strike Prices')

# Show the plot
plt.grid()
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt


# Extract the year from 'QUOTE_DATE' and create a new column 'QUOTE_YEAR'
df['QUOTE_YEAR'] = df['QUOTE_DATE'].dt.year

# Group the data by 'QUOTE_YEAR' and 'STRIKE', then count the occurrences
strike_counts_by_year = df.groupby(['QUOTE_YEAR', 'STRIKE']).size().reset_index(name='COUNT')

# Create a bar chart to show the count of unique strike prices for each year
plt.figure(figsize=(12, 6))  # Set the figure size

# Plot the count of unique strike prices by year using a bar chart
plt.bar(strike_counts_by_year['QUOTE_YEAR'], strike_counts_by_year['COUNT'], alpha=0.7)

# Customize the plot
plt.title('Count of Unique Strike Prices by Year')
plt.xlabel('Year')
plt.ylabel('Count of Unique Strike Prices')

# Show the plot
plt.grid()
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Extract the year from 'QUOTE_DATE' and create a new column 'QUOTE_YEAR'
df['QUOTE_YEAR'] = df['QUOTE_DATE'].dt.year

# Group the data by 'QUOTE_YEAR' and 'STRIKE', then count the occurrences
strike_counts_by_year = df.groupby(['QUOTE_YEAR', 'STRIKE']).size().reset_index(name='COUNT')

# Get unique years from the data
years = strike_counts_by_year['QUOTE_YEAR'].unique()

# Create a grouped bar chart for strike prices and counts for each year
plt.figure(figsize=(12, 6))  # Set the figure size

# Iterate through years and plot strike prices and counts
for year in years:
    data_year = strike_counts_by_year[strike_counts_by_year['QUOTE_YEAR'] == year]
    plt.bar(data_year['STRIKE'], data_year['COUNT'], label=str(year), alpha=0.7)

# Customize the plot
plt.title('Strike Prices and Counts for Each Year')
plt.xlabel('Strike Price')
plt.ylabel('Count')
plt.legend(title='Year')

# Show the plot
plt.grid()
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Extract the year from 'QUOTE_DATE' and create a new column 'QUOTE_YEAR'
df['QUOTE_YEAR'] = df['QUOTE_DATE'].dt.year

# Group the data by 'QUOTE_YEAR' and 'STRIKE', then count the occurrences
strike_counts_by_year = df.groupby(['QUOTE_YEAR', 'STRIKE']).size().reset_index(name='COUNT')

# Get unique years from the data
years = strike_counts_by_year['QUOTE_YEAR'].unique()

# Set the number of columns for subplots
num_cols = 3  # You can adjust the number of columns as needed
num_rows = (len(years) + num_cols - 1) // num_cols

# Create subplots with Seaborn style
plt.figure(figsize=(15, 10))

for i, year in enumerate(years):
    data_year = strike_counts_by_year[strike_counts_by_year['QUOTE_YEAR'] == year]
    plt.subplot(num_rows, num_cols, i + 1)
    sns.barplot(data=data_year, x='STRIKE', y='COUNT', palette='viridis', alpha=0.8)
    plt.title(f'Year {year}', fontsize=14)
    plt.xlabel('Strike Price', fontsize=12)
    plt.ylabel('Count', fontsize=12)
    plt.xticks(rotation=45)
    plt.tight_layout()

# Remove any empty subplots
if len(years) < num_cols * num_rows:
    for i in range(len(years), num_cols * num_rows):
        plt.delaxes(plt.subplot(num_rows, num_cols, i + 1))

# Add a main title
plt.suptitle('Strike Prices and Counts for Each Year', fontsize=16, y=1.02)

# Show the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Sample data (you can replace this with your loaded data)
# df = ...

# Extract the year from 'QUOTE_DATE' and create a new column 'QUOTE_YEAR'
df['QUOTE_YEAR'] = df['QUOTE_DATE'].dt.year

# Group the data by 'QUOTE_YEAR' and 'STRIKE', then count the occurrences
strike_counts_by_year = df.groupby(['QUOTE_YEAR', 'STRIKE']).size().reset_index(name='COUNT')

# Get unique years from the data
years = strike_counts_by_year['QUOTE_YEAR'].unique()

# Set the number of columns for subplots
num_cols = 3  # You can adjust the number of columns as needed
num_rows = (len(years) + num_cols - 1) // num_cols

# Create subplots with Seaborn style
plt.figure(figsize=(15, 10))

for i, year in enumerate(years):
    data_year = strike_counts_by_year[strike_counts_by_year['QUOTE_YEAR'] == year]

    # Filter and display a subset of strike prices (e.g., top 10)
    top_strike_prices = data_year.sort_values(by='COUNT', ascending=False).head(10)

    plt.subplot(num_rows, num_cols, i + 1)
    sns.barplot(data=top_strike_prices, x='STRIKE', y='COUNT', palette='viridis', alpha=0.8)
    plt.title(f'Year {year}', fontsize=14)
    plt.xlabel('Strike Price', fontsize=12)
    plt.ylabel('Count', fontsize=12)
    plt.xticks(rotation=45)
    plt.tight_layout()

# Remove any empty subplots
if len(years) < num_cols * num_rows:
    for i in range(len(years), num_cols * num_rows):
        plt.delaxes(plt.subplot(num_rows, num_cols, i + 1))

# Add a main title
plt.suptitle('Top 10 Strike Prices and Counts for Each Year', fontsize=16, y=1.02)

# Show the plot
plt.tight_layout()
plt.show()

# %%
import pandas as pd

# Sample data (you can replace this with your loaded data)
# df = ...

# Group the data by 'STRIKE' and count the occurrences
strike_counts = df['STRIKE'].value_counts().reset_index()
strike_counts.columns = ['STRIKE', 'COUNT']

# Display the table of strike prices and their counts
strike_counts.head(25)
# Out:
#     STRIKE  COUNT
# 0    160.0  18703
# 1    150.0  18534
# 2    170.0  18395
# 3    165.0  18124
# 4    155.0  18087
# 5    175.0  17829
# 6    180.0  17487
# 7    145.0  17404
# 8    140.0  17382
# 9    185.0  16181
# 10   130.0  16047
# 11   135.0  15487
# 12   190.0  15437
# 13   200.0  15298
# 14   120.0  15226
# 15   125.0  14591
# 16   195.0  14381
# 17   100.0  13709
# 18   110.0  13082
# 19   115.0  12775
# 20   210.0  11413
# 21   105.0  10718
# 22   220.0  10135
# 23    90.0   9576
# 24    95.0   9461

# %% [markdown]
# # Explore Contracts: Strike Prices and Volume

# %%
import matplotlib.pyplot as plt
# Sample data (you can replace this with your loaded data)
# df = ...

# Create a bar chart of strike prices and call option volumes
plt.figure(figsize=(12, 6))
plt.bar(df['STRIKE'], df['C_VOLUME'], color='skyblue', edgecolor='black')

# Set axis labels and title
plt.xlabel('Strike Price')
plt.ylabel('Call Option Volume (C_VOLUME)')
plt.title('Call Option Volume by Strike Price')

# Show the plot
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-77f020703a34> in <cell line: 7>()
#       5 # Create a bar chart of strike prices and call option volumes
#       6 plt.figure(figsize=(12, 6))
# ----> 7 plt.bar(df['STRIKE'], df['C_VOLUME'], color='skyblue', edgecolor='black')
#       8
#       9 # Set axis labels and title
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py in bar(x, height, width, bottom, align, data, **kwargs)
#    2437         x, height, width=0.8, bottom=None, *, align='center',
#    2438         data=None, **kwargs):
# -> 2439     return gca().bar(
#    2440         x, height, width=width, bottom=bottom, align=align,
#    2441         **({"data": data} if data is not None else {}), **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Sample data (you can replace this with your loaded data)
# df = ...

# Create a histogram to show the distribution of call option volumes by strike price
plt.figure(figsize=(12, 6))  # Set the figure size

# Plot a histogram of call option volumes (C_VOLUME) by strike price
plt.hist(df['C_VOLUME'], bins=30, edgecolor='k', alpha=0.7, color='skyblue')

# Customize the plot
plt.title('Distribution of Call Option Volumes by Strike Price')
plt.xlabel('Call Option Volume (C_VOLUME)')
plt.ylabel('Count')

# Show the plot
plt.grid()
plt.tight_layout()
plt.show()

# %%
import pandas as pd

# Sample data (you can replace this with your loaded data)
# df = ...

# Extract the year from the 'QUOTE_DATE' column and create a new 'QUOTE_YEAR' column
df['QUOTE_DATE'] = pd.to_datetime(df['QUOTE_DATE'])  # Ensure 'QUOTE_DATE' is in datetime format
df['QUOTE_YEAR'] = df['QUOTE_DATE'].dt.year

# Create a new DataFrame with 'STRIKE', 'QUOTE_YEAR', and 'C_VOLUME'
strike_volume_df = df[['STRIKE', 'QUOTE_YEAR', 'C_VOLUME']]

# Group the data by 'STRIKE' and 'QUOTE_YEAR', and calculate the sum of 'C_VOLUME' for each combination
strike_volume_sum = strike_volume_df.groupby(['STRIKE', 'QUOTE_YEAR'])['C_VOLUME'].sum().reset_index()

# Sort the DataFrame by 'C_VOLUME' in descending order
sorted_df = strike_volume_sum.sort_values(by='C_VOLUME', ascending=False)

# Select the top N strike prices (e.g., top 10)
top_strike_prices = sorted_df.head(10)

# Print the list of top strike prices, along with year and volume
print("Top Strike Prices by Call Option Volume:")
print(top_strike_prices)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Sample data (you can replace this with your loaded data)
# df = ...

# Ensure 'QUOTE_DATE' is in datetime format
df['QUOTE_DATE'] = pd.to_datetime(df['QUOTE_DATE'])

# Create a line plot of call option volume over time
plt.figure(figsize=(12, 6))
plt.plot(df['QUOTE_DATE'], df['C_VOLUME'], marker='o', linestyle='-')

# Set axis labels and title
plt.xlabel('Date')
plt.ylabel('Call Option Volume (C_VOLUME)')
plt.title('Call Option Volume Over Time')

# Show the plot
plt.grid()
plt.tight_layout()
plt.show()

# %% [markdown]
# ```
# # This is formatted as code
# ```
#
# # Explore Expiry Date

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming you have already loaded your DataFrame 'df'

# Extract contract expiry dates
expiry_dates = df['EXPIRE_DATE']

# Plot a histogram of contract expiry dates
plt.figure(figsize=(10, 6))
plt.hist(expiry_dates, bins=30, edgecolor='k')
plt.xlabel('Contract Expiry Dates')
plt.ylabel('Count')
plt.title('Distribution of Contract Expiry Dates')
plt.xticks(rotation=45)
plt.tight_layout()

# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming 'df' is your DataFrame with option contract data

# Convert 'EXPIRE_DATE' to a pandas datetime object if it's not already
df['EXPIRE_DATE'] = pd.to_datetime(df['EXPIRE_DATE'])

# Filter the DataFrame for contracts in the year 2019
year_2019_contracts = df[df['EXPIRE_DATE'].dt.year == 2019]

# Group the contracts by 'STRIKE' and calculate the mean of 'C_LAST' for each strike price
top_10_contracts = year_2019_contracts.groupby('STRIKE')['C_LAST'].mean().nlargest(10)

# Plot the 10 best contracts by strike price and their average 'C_LAST'
plt.figure(figsize=(12, 6))
top_10_contracts.plot(kind='bar', edgecolor='k')
plt.title('Top 10 Option Contracts by Average C_LAST Price (Year 2019)')
plt.xlabel('Strike Price')
plt.ylabel('Average C_LAST Price')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Explore Price Charts

# %%
import pandas as pd
import matplotlib.pyplot as plt
import random

# Assuming 'df' is your DataFrame with option contract data

# Choose a random contract from the DataFrame
random_contract = df.sample(1)

# Extract the contract's 'STRIKE', 'EXPIRE_DATE', and 'DTE' values
strike_price = random_contract['STRIKE'].values[0]
expire_date = random_contract['EXPIRE_DATE'].values[0]
dte = random_contract['DTE'].values[0]

# Filter the DataFrame for the selected contract
selected_contract = df[(df['STRIKE'] == strike_price) & (df['EXPIRE_DATE'] == expire_date)]

# Sort the DataFrame by 'QUOTE_DATE' for a time series plot
selected_contract = selected_contract.sort_values(by='QUOTE_DATE')

# Create a figure and primary and secondary y-axes
fig, ax1 = plt.subplots(figsize=(12, 6))
ax2 = ax1.twinx()

# Plot 'C_LAST' and 'UNDERLYING_LAST' on the primary y-axis
ax1.plot(selected_contract['QUOTE_DATE'], selected_contract['C_LAST'], marker='o', linestyle='-', markersize=3, label='C_LAST')
ax1.plot(selected_contract['QUOTE_DATE'], selected_contract['UNDERLYING_LAST'], marker='o', linestyle='-', markersize=3, label='UNDERLYING_LAST')

# Plot 'DTE' on the secondary y-axis
ax2.plot(selected_contract['QUOTE_DATE'], selected_contract['DTE'], color='red', marker='x', linestyle='--', markersize=5, label=f'DTE: {dte}')

# Set labels, title, and legends
ax1.set_xlabel('QUOTE_DATE')
ax1.set_ylabel('Price')
ax2.set_ylabel('DTE', color='red')
plt.xticks(rotation=45)

# Combine legends from both axes
lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
lines = lines1 + lines2
labels = labels1 + labels2

# Display combined legend
plt.legend(lines, labels, loc='upper left')

# Show the plot
plt.grid(True)
plt.title(f'Option Contract (Strike Price: {strike_price}, Expiry Date: {expire_date}) Over Time')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import random

# Assuming 'df' is your DataFrame with option contract data

# Choose a random contract from the DataFrame
random_contract = df.sample(1)

# Extract the contract's 'STRIKE', 'EXPIRE_DATE', 'DTE', and 'UNDERLYING_LAST' values
strike_price = random_contract['STRIKE'].values[0]
expire_date = random_contract['EXPIRE_DATE'].values[0]
underlying_last = random_contract['UNDERLYING_LAST'].values[0]

# Filter the DataFrame for the selected contract
selected_contract = df[(df['STRIKE'] == strike_price) & (df['EXPIRE_DATE'] == expire_date)]

# Sort the DataFrame by 'QUOTE_DATE' for a time series plot
selected_contract = selected_contract.sort_values(by='QUOTE_DATE')

# Calculate the percentage change from the first day to the last day for C_LAST
first_day_price_c = selected_contract['C_LAST'].iloc[0]
last_day_price_c = selected_contract['C_LAST'].iloc[-1]
percentage_change_c = ((last_day_price_c - first_day_price_c) / first_day_price_c) * 100

# Calculate the percentage change from the first day to the last day for UNDERLYING_LAST
first_day_price_underlying = selected_contract['UNDERLYING_LAST'].iloc[0]
last_day_price_underlying = selected_contract['UNDERLYING_LAST'].iloc[-1]
percentage_change_underlying = ((last_day_price_underlying - first_day_price_underlying) / first_day_price_underlying) * 100

# Create a line plot of 'QUOTE_DATE' against 'C_LAST'
plt.figure(figsize=(12, 6))
plt.plot(selected_contract['QUOTE_DATE'], selected_contract['C_LAST'], marker='o', linestyle='-', markersize=3, label='C_LAST')
plt.plot(selected_contract['QUOTE_DATE'], selected_contract['UNDERLYING_LAST'], marker='x', linestyle='-', markersize=3, label='UNDERLYING_LAST')

# Set labels and title
plt.xlabel('QUOTE_DATE')
plt.ylabel('Price')
plt.xticks(rotation=45)
plt.grid(True)
plt.title(f'Option Contract (Strike Price: {strike_price}, Expiry Date: {expire_date}) Over Time\n'
          f'Percentage Change from First Day to Last Day:\n'
          f'C_LAST: {percentage_change_c:.2f}%\n'
          f'UNDERLYING_LAST: {percentage_change_underlying:.2f}%')

# Add a legend to distinguish C_LAST and UNDERLYING_LAST
plt.legend()

# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import random

# Assuming 'df' is your DataFrame with option contract data

# Choose a random contract from the DataFrame
random_contract = df.sample(1)

# Extract the contract's relevant information
strike_price = random_contract['STRIKE'].values[0]
expire_date = random_contract['EXPIRE_DATE'].values[0]
underlying_last = random_contract['UNDERLYING_LAST'].values[0]

# Filter the DataFrame for the selected contract
selected_contract = df[(df['STRIKE'] == strike_price) & (df['EXPIRE_DATE'] == expire_date)]

# Sort the DataFrame by 'QUOTE_DATE' for a time series plot
selected_contract = selected_contract.sort_values(by='QUOTE_DATE')

# Calculate the percentage change from the first day to the last day for 'C_LAST'
initial_c_last = selected_contract['C_LAST'].iloc[0]
final_c_last = selected_contract['C_LAST'].iloc[-1]
percentage_change_c_last = ((final_c_last - initial_c_last) / initial_c_last) * 100

# Calculate the percentage change from the first day to the last day for 'UNDERLYING_LAST'
initial_underlying_last = selected_contract['UNDERLYING_LAST'].iloc[0]
final_underlying_last = selected_contract['UNDERLYING_LAST'].iloc[-1]
percentage_change_underlying_last = ((final_underlying_last - initial_underlying_last) / initial_underlying_last) * 100

# Find the date with the highest percentage change for 'C_LAST'
max_c_last_date = selected_contract['QUOTE_DATE'][selected_contract['C_LAST'].idxmax()]

# Find the date with the highest percentage change for 'UNDERLYING_LAST'
max_underlying_last_date = selected_contract['QUOTE_DATE'][selected_contract['UNDERLYING_LAST'].idxmax()]

# Create a line plot of 'QUOTE_DATE' against 'C_LAST' and 'UNDERLYING_LAST'
plt.figure(figsize=(12, 6))
plt.plot(selected_contract['QUOTE_DATE'], selected_contract['C_LAST'], marker='o', linestyle='-', markersize=3, label='C_LAST')
plt.plot(selected_contract['QUOTE_DATE'], selected_contract['UNDERLYING_LAST'], marker='x', linestyle='-', markersize=3, label='UNDERLYING_LAST')

# Set labels and title for the plot
plt.xlabel('QUOTE_DATE')
plt.ylabel('Price')
plt.xticks(rotation=45)
plt.grid(True)
plt.title(f'Option Contract (Strike Price: {strike_price}, Expiry Date: {expire_date}) Over Time\n'
          f'Percentage Change from First Day to Last Day:\n'
          f'C_LAST: {percentage_change_c_last:.2f}% (Max Gain on {max_c_last_date})\n'
          f'UNDERLYING_LAST: {percentage_change_underlying_last:.2f}% (Max Gain on {max_underlying_last_date})')

# Highlight the points with the maximum gains
plt.scatter(max_c_last_date, selected_contract['C_LAST'].max(), color='red', marker='*', s=100, label='Max Gain (C_LAST)')
plt.scatter(max_underlying_last_date, selected_contract['UNDERLYING_LAST'].max(), color='green', marker='*', s=100, label='Max Gain (UNDERLYING_LAST)')

# Add a legend to distinguish 'C_LAST' and 'UNDERLYING_LAST'
plt.legend()

# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import random

# Assuming 'df' is your DataFrame with option contract data

# Choose a random contract from the DataFrame
random_contract = df.sample(1)

# Extract the contract's relevant information
strike_price = random_contract['STRIKE'].values[0]
expire_date = random_contract['EXPIRE_DATE'].values[0]
underlying_last = random_contract['UNDERLYING_LAST'].values[0]

# Filter the DataFrame for the selected contract
selected_contract = df[(df['STRIKE'] == strike_price) & (df['EXPIRE_DATE'] == expire_date)]

# Sort the DataFrame by 'QUOTE_DATE' for a time series plot
selected_contract = selected_contract.sort_values(by='QUOTE_DATE')

# Calculate the percentage change from the first day to the last day for C_LAST
first_day_price_c = selected_contract['C_LAST'].iloc[0]
last_day_price_c = selected_contract['C_LAST'].iloc[-1]
percentage_change_c = ((last_day_price_c - first_day_price_c) / first_day_price_c) * 100

# Calculate the percentage change from the first day to the last day for UNDERLYING_LAST
first_day_price_underlying = selected_contract['UNDERLYING_LAST'].iloc[0]
last_day_price_underlying = selected_contract['UNDERLYING_LAST'].iloc[-1]
percentage_change_underlying = ((last_day_price_underlying - first_day_price_underlying) / first_day_price_underlying) * 100

# Identify the minimum and maximum values for C_LAST and UNDERLYING_LAST
min_c_last = selected_contract['C_LAST'].min()
max_c_last = selected_contract['C_LAST'].max()
min_underlying_last = selected_contract['UNDERLYING_LAST'].min()
max_underlying_last = selected_contract['UNDERLYING_LAST'].max()

# Find the dates corresponding to the minimum and maximum values for C_LAST and UNDERLYING_LAST
date_min_c_last = selected_contract[selected_contract['C_LAST'] == min_c_last]['QUOTE_DATE'].values[0]
date_max_c_last = selected_contract[selected_contract['C_LAST'] == max_c_last]['QUOTE_DATE'].values[0]
date_min_underlying_last = selected_contract[selected_contract['UNDERLYING_LAST'] == min_underlying_last]['QUOTE_DATE'].values[0]
date_max_underlying_last = selected_contract[selected_contract['UNDERLYING_LAST'] == max_underlying_last]['QUOTE_DATE'].values[0]

# Calculate the percentage gain from the minimum to the maximum for C_LAST and UNDERLYING_LAST
percentage_gain_c_last = 0  # Initialize to zero
percentage_gain_underlying_last = 0  # Initialize to zero

# Check if minimum date is before maximum date for C_LAST
if date_min_c_last < date_max_c_last:
    percentage_gain_c_last = ((max_c_last - min_c_last) / min_c_last) * 100

# Check if minimum date is before maximum date for UNDERLYING_LAST
if date_min_underlying_last < date_max_underlying_last:
    percentage_gain_underlying_last = ((max_underlying_last - min_underlying_last) / min_underlying_last) * 100

# Calculate the number of days it took to reach the maximum from the minimum for C_LAST and UNDERLYING_LAST
days_to_max_c_last = (date_max_c_last - date_min_c_last).astype('timedelta64[D]').astype(int)
days_to_max_underlying_last = (date_max_underlying_last - date_min_underlying_last).astype('timedelta64[D]').astype(int)

# Check if the number of days is non-negative; if negative, indicate no gains
if days_to_max_c_last < 0:
    days_to_max_c_last_text = 'No Gains'
else:
    days_to_max_c_last_text = f'{days_to_max_c_last} days'

if days_to_max_underlying_last < 0:
    days_to_max_underlying_last_text = 'No Gains'
else:
    days_to_max_underlying_last_text = f'{days_to_max_underlying_last} days'

# Create a line plot of 'QUOTE_DATE' against 'C_LAST'
plt.figure(figsize=(12, 6))
plt.plot(selected_contract['QUOTE_DATE'], selected_contract['C_LAST'], marker='o', linestyle='-', markersize=3, label='C_LAST')
plt.plot(selected_contract['QUOTE_DATE'], selected_contract['UNDERLYING_LAST'], marker='x', linestyle='-', markersize=3, label='UNDERLYING_LAST')

# Mark the minimum and maximum points with vertical dashed lines
plt.axvline(x=date_min_c_last, color='red', linestyle='--', label='Min (C_LAST)')
plt.axvline(x=date_max_c_last, color='blue', linestyle='--', label='Max (C_LAST)')
plt.axvline(x=date_min_underlying_last, color='green', linestyle='--', label='Min (UNDERLYING_LAST)')
plt.axvline(x=date_max_underlying_last, color='purple', linestyle='--', label='Max (UNDERLYING_LAST)')

# Set labels and title
plt.xlabel('QUOTE_DATE')
plt.ylabel('Price')
plt.xticks(rotation=45)
plt.grid(True)
plt.title(f'Option Contract (Strike Price: {strike_price}, Expiry Date: {expire_date}) Over Time\n'
          f'Percentage Change from First Day to Last Day:\n'
          f'C_LAST: {percentage_change_c:.2f}%\n'
          f'UNDERLYING_LAST: {percentage_change_underlying:.2f}%\n'
          f'Percentage Gain from Min to Max:\n'
          f'C_LAST: {percentage_gain_c_last:.2f}% in {days_to_max_c_last_text}\n'
          f'UNDERLYING_LAST: {percentage_gain_underlying_last:.2f}% in {days_to_max_underlying_last_text}')

# Add a legend to distinguish C_LAST and UNDERLYING_LAST
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# # Add new columns to the dataframe

# %%
import pandas as pd
import random

# Assuming 'df' is your DataFrame with option contract data

# Calculate the percentage change from the first day to the last day for C_LAST for all rows
df['Percentage Change C_LAST'] = (df.groupby(['STRIKE', 'EXPIRE_DATE'])['C_LAST'].transform(lambda x: (x.iloc[-1] - x.iloc[0]) / x.iloc[0] * 100))

# Calculate the percentage change from the first day to the last day for UNDERLYING_LAST for all rows
df['Percentage Change UNDERLYING_LAST'] = (df.groupby(['STRIKE', 'EXPIRE_DATE'])['UNDERLYING_LAST'].transform(lambda x: (x.iloc[-1] - x.iloc[0]) / x.iloc[0] * 100))

# Identify the minimum and maximum values for C_LAST and UNDERLYING_LAST for all rows
df['Min C_LAST'] = df.groupby(['STRIKE', 'EXPIRE_DATE'])['C_LAST'].transform('min')
df['Max C_LAST'] = df.groupby(['STRIKE', 'EXPIRE_DATE'])['C_LAST'].transform('max')
df['Min UNDERLYING_LAST'] = df.groupby(['STRIKE', 'EXPIRE_DATE'])['UNDERLYING_LAST'].transform('min')
df['Max UNDERLYING_LAST'] = df.groupby(['STRIKE', 'EXPIRE_DATE'])['UNDERLYING_LAST'].transform('max')

# Calculate the percentage gain from the minimum to the maximum for C_LAST for all rows
df['Percentage Gain C_LAST'] = df.apply(lambda row: ((row['Max C_LAST'] - row['Min C_LAST']) / row['Min C_LAST']) * 100 if row['Min C_LAST'] < row['Max C_LAST'] else None, axis=1)

# Calculate the percentage gain from the minimum to the maximum for UNDERLYING_LAST for all rows
df['Percentage Gain UNDERLYING_LAST'] = df.apply(lambda row: ((row['Max UNDERLYING_LAST'] - row['Min UNDERLYING_LAST']) / row['Min UNDERLYING_LAST']) * 100 if row['Min UNDERLYING_LAST'] < row['Max UNDERLYING_LAST'] else None, axis=1)

# Calculate the number of days it took to reach the maximum from the minimum for C_LAST for all rows
df['Days to Max C_LAST'] = df.apply(lambda row: (row['QUOTE_DATE'] - df[(df['STRIKE'] == row['STRIKE']) & (df['EXPIRE_DATE'] == row['EXPIRE_DATE']) & (df['C_LAST'] == row['Max C_LAST'])]['QUOTE_DATE'].min()).days if row['Min C_LAST'] < row['Max C_LAST'] else None, axis=1)

# Calculate the number of days it took to reach the maximum from the minimum for UNDERLYING_LAST for all rows
df['Days to Max UNDERLYING_LAST'] = df.apply(lambda row: (row['QUOTE_DATE'] - df[(df['STRIKE'] == row['STRIKE']) & (df['EXPIRE_DATE'] == row['EXPIRE_DATE']) & (df['UNDERLYING_LAST'] == row['Max UNDERLYING_LAST'])]['QUOTE_DATE'].min()).days if row['Min UNDERLYING_LAST'] < row['Max UNDERLYING_LAST'] else None, axis=1)

# Save the updated DataFrame as a new CSV file
#merged_output_path = '/content/drive/My Drive/Call Options Alert System/Options_data_calculated.csv'
#df.to_csv(merged_output_path, index=False)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-15712ae66db8> in <cell line: 25>()
#      23
#      24 # Calculate the number of days it took to reach the maximum from the minimum for C_LAST for all rows
# ---> 25 df['Days to Max C_LAST'] = df.apply(lambda row: (row['QUOTE_DATE'] - df[(df['STRIKE'] == row['STRIKE']) & (df['EXPIRE_DATE'] == row['EXPIRE_DATE']) & (df['C_LAST'] == row['Max C_LAST'])]['QUOTE_DATE'].min()).days if row['Min C_LAST'] < row['Max C_LAST'] else None, axis=1)
#      26
#      27 # Calculate the number of days it took to reach the maximum from the minimum for UNDERLYING_LAST for all rows
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in apply(self, func, axis, raw, result_type, args, **kwargs)
#    9566             kwargs=kwargs,
#    9567         )
# -> 9568         return op.apply().__finalize__(self, method="apply")
# ...

# %%
# Code to add calculated columns to df
# (Please make sure this code was executed before listing the columns)
import pandas as pd
import random

# Assuming 'df' is your DataFrame with option contract data

# Calculate the percentage change from the first day to the last day for C_LAST for all rows
df['Percentage Change C_LAST'] = (df.groupby(['STRIKE', 'EXPIRE_DATE'])['C_LAST'].transform(lambda x: (x.iloc[-1] - x.iloc[0]) / x.iloc[0] * 100))

# Calculate the percentage change from the first day to the last day for UNDERLYING_LAST for all rows
df['Percentage Change UNDERLYING_LAST'] = (df.groupby(['STRIKE', 'EXPIRE_DATE'])['UNDERLYING_LAST'].transform(lambda x: (x.iloc[-1] - x.iloc[0]) / x.iloc[0] * 100))

# Identify the minimum and maximum values for C_LAST and UNDERLYING_LAST for all rows
df['Min C_LAST'] = df.groupby(['STRIKE', 'EXPIRE_DATE'])['C_LAST'].transform('min')
df['Max C_LAST'] = df.groupby(['STRIKE', 'EXPIRE_DATE'])['C_LAST'].transform('max')
df['Min UNDERLYING_LAST'] = df.groupby(['STRIKE', 'EXPIRE_DATE'])['UNDERLYING_LAST'].transform('min')
df['Max UNDERLYING_LAST'] = df.groupby(['STRIKE', 'EXPIRE_DATE'])['UNDERLYING_LAST'].transform('max')

# Calculate the percentage gain from the minimum to the maximum for C_LAST for all rows
df['Percentage Gain C_LAST'] = df.apply(lambda row: ((row['Max C_LAST'] - row['Min C_LAST']) / row['Min C_LAST']) * 100 if row['Min C_LAST'] < row['Max C_LAST'] else None, axis=1)

# Calculate the percentage gain from the minimum to the maximum for UNDERLYING_LAST for all rows
df['Percentage Gain UNDERLYING_LAST'] = df.apply(lambda row: ((row['Max UNDERLYING_LAST'] - row['Min UNDERLYING_LAST']) / row['Min UNDERLYING_LAST']) * 100 if row['Min UNDERLYING_LAST'] < row['Max UNDERLYING_LAST'] else None, axis=1)

# %%
df.head(4)
# Out:
#   QUOTE_DATE  UNDERLYING_LAST EXPIRE_DATE  EXPIRE_UNIX     DTE  C_DELTA  \
# 0 2016-01-04           105.35  2016-07-15   1468612800  192.96  0.26181
# 1 2016-01-04           105.35  2016-04-15   1460750400  101.96  0.70669
# 2 2016-01-04           105.35  2016-04-15   1460750400  101.96  0.65154
# 3 2016-01-04           105.35  2016-04-15   1460750400  101.96  0.28002
#
#    C_GAMMA   C_VEGA  C_THETA    C_RHO  ...  STRIKE_DISTANCE  \
# 0  0.01644  0.24937 -0.01543  0.12803  ...             14.7
# 1  0.02061  0.19101 -0.02613  0.15454  ...              7.8
# 2  0.02256  0.20611 -0.02747  0.14980  ...              5.3
# 3  0.02283  0.18816 -0.02274  0.07569  ...              9.7
#
#    STRIKE_DISTANCE_PCT  Percentage Change C_LAST  \
# 0                0.139                -99.613900
# 1                0.075                 21.895735
# 2                0.051                 20.329670
# 3                0.092                -94.117647
#
# ...

# %% [markdown]
# # Finding Best Contracts

# %%
import pandas as pd

# Assuming 'df' is your DataFrame with the calculated columns

# Calculate the 90th percentile of Percentage Change C_LAST
percentile_90 = df['Percentage Change C_LAST'].quantile(0.90)

# Select the top 10% percentile values
top_10_percentile_df = df[df['Percentage Change C_LAST'] >= percentile_90]

# Count the number of rows in the top 10% percentile
num_rows_in_10_percentile = top_10_percentile_df.shape[0]

print(f"Number of Rows in the Top 10% Percentile: {num_rows_in_10_percentile}")
# Out:
# Number of Rows in the Top 10% Percentile: 74410

# %%
import pandas as pd
import matplotlib.pyplot as plt
import random

# Assuming 'df' is your DataFrame with option contract data

# Find the contract with the highest Percentage Change C_LAST
highest_change_contract = df[df['Percentage Change C_LAST'] == df['Percentage Change C_LAST'].max()]

# Extract the relevant information
strike_price = highest_change_contract['STRIKE'].values[0]
expire_date = highest_change_contract['EXPIRE_DATE'].values[0]
underlying_last = highest_change_contract['UNDERLYING_LAST'].values[0]

# Filter the DataFrame for the selected contract
selected_contract = df[(df['STRIKE'] == strike_price) & (df['EXPIRE_DATE'] == expire_date)]

# Sort the DataFrame by 'QUOTE_DATE' for a time series plot
selected_contract = selected_contract.sort_values(by='QUOTE_DATE')

# Calculate the percentage change from the first day to the last day for C_LAST
first_day_price_c = selected_contract['C_LAST'].iloc[0]
last_day_price_c = selected_contract['C_LAST'].iloc[-1]
percentage_change_c = ((last_day_price_c - first_day_price_c) / first_day_price_c) * 100

# Identify the minimum and maximum values for C_LAST and UNDERLYING_LAST
min_c_last = selected_contract['C_LAST'].min()
max_c_last = selected_contract['C_LAST'].max()
min_underlying_last = selected_contract['UNDERLYING_LAST'].min()
max_underlying_last = selected_contract['UNDERLYING_LAST'].max()

# Find the dates corresponding to the minimum and maximum values for C_LAST and UNDERLYING_LAST
date_min_c_last = selected_contract[selected_contract['C_LAST'] == min_c_last]['QUOTE_DATE'].values[0]
date_max_c_last = selected_contract[selected_contract['C_LAST'] == max_c_last]['QUOTE_DATE'].values[0]
date_min_underlying_last = selected_contract[selected_contract['UNDERLYING_LAST'] == min_underlying_last]['QUOTE_DATE'].values[0]
date_max_underlying_last = selected_contract[selected_contract['UNDERLYING_LAST'] == max_underlying_last]['QUOTE_DATE'].values[0]

# Calculate the percentage gain from the minimum to the maximum for C_LAST and UNDERLYING_LAST
percentage_gain_c_last = 0  # Initialize to zero
percentage_gain_underlying_last = 0  # Initialize to zero

# Check if minimum date is before maximum date for C_LAST
if date_min_c_last < date_max_c_last:
    percentage_gain_c_last = ((max_c_last - min_c_last) / min_c_last) * 100

# Check if minimum date is before maximum date for UNDERLYING_LAST
if date_min_underlying_last < date_max_underlying_last:
    percentage_gain_underlying_last = ((max_underlying_last - min_underlying_last) / min_underlying_last) * 100

# Calculate the number of days it took to reach the maximum from the minimum for C_LAST and UNDERLYING_LAST
days_to_max_c_last = (date_max_c_last - date_min_c_last).astype('timedelta64[D]').astype(int)
days_to_max_underlying_last = (date_max_underlying_last - date_min_underlying_last).astype('timedelta64[D]').astype(int)

# Check if the number of days is non-negative; if negative, indicate no gains
if days_to_max_c_last < 0:
    days_to_max_c_last_text = 'No Gains'
else:
    days_to_max_c_last_text = f'{days_to_max_c_last} days'

if days_to_max_underlying_last < 0:
    days_to_max_underlying_last_text = 'No Gains'
else:
    days_to_max_underlying_last_text = f'{days_to_max_underlying_last} days'

# Create a line plot of 'QUOTE_DATE' against 'C_LAST'
plt.figure(figsize=(12, 6))
plt.plot(selected_contract['QUOTE_DATE'], selected_contract['C_LAST'], marker='o', linestyle='-', markersize=3, label='C_LAST')
plt.plot(selected_contract['QUOTE_DATE'], selected_contract['UNDERLYING_LAST'], marker='x', linestyle='-', markersize=3, label='UNDERLYING_LAST')

# Mark the minimum and maximum points with vertical dashed lines
plt.axvline(x=date_min_c_last, color='red', linestyle='--', label='Min (C_LAST)')
plt.axvline(x=date_max_c_last, color='blue', linestyle='--', label='Max (C_LAST)')
plt.axvline(x=date_min_underlying_last, color='green', linestyle='--', label='Min (UNDERLYING_LAST)')
plt.axvline(x=date_max_underlying_last, color='purple', linestyle='--', label='Max (UNDERLYING_LAST)')

# Set labels and title
plt.xlabel('QUOTE_DATE')
plt.ylabel('Price')
plt.xticks(rotation=45)
plt.grid(True)
plt.title(f'Option Contract (Strike Price: {strike_price}, Expiry Date: {expire_date}) Over Time\n'
          f'Percentage Change from First Day to Last Day:\n'
          f'C_LAST: {percentage_change_c:.2f}%\n'
          f'UNDERLYING_LAST: {percentage_change_underlying:.2f}%\n'
          f'Percentage Gain from Min to Max:\n'
          f'C_LAST: {percentage_gain_c_last:.2f}% in {days_to_max_c_last_text}\n'
          f'UNDERLYING_LAST: {percentage_gain_underlying_last:.2f}% in {days_to_max_underlying_last_text}')

# Add a legend to distinguish C_LAST and UNDERLYING_LAST
plt.legend()

# Show the plot
plt.show()

# %%
# Assuming 'df' is your DataFrame with calculated columns

# Calculate the number of unique values in the 'Percentage Change C_LAST' column
unique_values = df['Percentage Change C_LAST'].nunique()

# Calculate the number of non-unique values (total values minus unique values)
total_values = len(df['Percentage Change C_LAST'])
non_unique_values = total_values - unique_values

# Display the number of unique and non-unique values
print(f'Number of unique values in Percentage Change C_LAST: {unique_values}')
print(f'Number of non-unique values in Percentage Change C_LAST: {non_unique_values}')
# Out:
# Number of unique values in Percentage Change C_LAST: 15421
# Number of non-unique values in Percentage Change C_LAST: 725353

# %% [markdown]
# # Marking rows with call option gains of 5%, 10%, 25%, 50%.

# %%
import pandas as pd

# Assuming 'df' is your DataFrame with the 'Percentage Change C_LAST' column

# Sort the DataFrame by 'Percentage Change C_LAST'
sorted_df = df.sort_values(by='Percentage Change C_LAST', ascending=True)

# Calculate the quantiles
quantiles = sorted_df['Percentage Change C_LAST'].quantile([0.05, 0.10, 0.25, 0.50])

# Add new columns to mark percentiles as 0 or 1
df['Percentile_5'] = (df['Percentage Change C_LAST'] <= quantiles[0.05]).astype(int)
df['Percentile_10'] = ((df['Percentage Change C_LAST'] > quantiles[0.05]) & (df['Percentage Change C_LAST'] <= quantiles[0.10])).astype(int)
df['Percentile_25'] = ((df['Percentage Change C_LAST'] > quantiles[0.10]) & (df['Percentage Change C_LAST'] <= quantiles[0.25])).astype(int)
df['Percentile_50'] = ((df['Percentage Change C_LAST'] > quantiles[0.25]) & (df['Percentage Change C_LAST'] <= quantiles[0.50])).astype(int)

# The new columns will contain 0 or 1 based on the respective percentiles

# You can now use these columns to filter or analyze data based on percentiles.

# Save the updated DataFrame as a new CSV file
#merged_output_path = '/content/drive/My Drive/Call Options Alert System/Options_data_calculated.csv'
#df.to_csv(merged_output_path, index=False)

# %%
df.head(4)
# Out:
#   QUOTE_DATE  UNDERLYING_LAST EXPIRE_DATE  EXPIRE_UNIX     DTE  C_DELTA  \
# 0 2016-01-04           105.35  2016-07-15   1468612800  192.96  0.26181
# 1 2016-01-04           105.35  2016-04-15   1460750400  101.96  0.70669
# 2 2016-01-04           105.35  2016-04-15   1460750400  101.96  0.65154
# 3 2016-01-04           105.35  2016-04-15   1460750400  101.96  0.28002
#
#    C_GAMMA   C_VEGA  C_THETA    C_RHO  ...  Min C_LAST  Max C_LAST  \
# 0  0.01644  0.24937 -0.01543  0.12803  ...        0.01        2.59
# 1  0.02061  0.19101 -0.02613  0.15454  ...        3.10       13.70
# 2  0.02256  0.20611 -0.02747  0.14980  ...        7.65       10.95
# 3  0.02283  0.18816 -0.02274  0.07569  ...        0.08        2.38
#
#    Min UNDERLYING_LAST Max UNDERLYING_LAST  Percentage Gain C_LAST  \
# 0                90.34              110.96            25800.000000
# 1                93.65              111.11              341.935484
# ...
